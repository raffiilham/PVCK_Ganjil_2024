# %% [markdown]
# <a href="https://colab.research.google.com/github/raffiilham/PVCK_Ganjil_2024/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  import folder yang ada di Drive

# %%
from google.colab import drive

#accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang
# sudah ada. Contohnya pada kode program di bawah file image dengan nama
# kitten01.jpg akan dibuka untuk diproses lebih lanjut.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten.jpg')
plt.imshow(img)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/images/kitten.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 =cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan File image
#cv.imwrite(/content/drive/MyDrive/PCVK/images/kitten.jpg,img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros((512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font =cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros((512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# ### **Pertanyaan**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# ### **Jawaban Pertanyaan**
# 1. Gambar tanpa matplotlib memiliki fleksibilitas dan tingkat detail yang tinggi, tetapi proses visualisasinya cenderung lebih lambat. Sebaliknya, gambar dengan matplotlib lebih efisien dalam hal visualisasi data dan lebih mudah dikustomisasi, meskipun tingkat kedetailannya mungkin tidak setinggi tanpa matplotlib.
#
# 2. Untuk gambar hitam tanpa persyaratan khusus atau penggunaan umum, tipe data `int16` sudah cukup. Namun, jika memerlukan akurasi dan presisi yang lebih tinggi, `int32` adalah pilihan yang lebih baik.
#
# 3. Fungsinya adalah sebagai penghubung antara Google Colab dan OpenCV untuk membaca gambar.
#
# 4. Digunakan dalam proses manipulasi gambar, seperti konversi, membaca, dan menulis gambar.

# %% [markdown]
# ## **E. TUGAS**
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
# ### **1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?**

# %%
# Membaca gambar
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten.jpg')

# Menampilkan gambar dengan figsize yang berbeda
fig = plt.figure(figsize=(10,10))  # Ukuran lebih besar
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

fig = plt.figure(figsize=(5,5))  # Ukuran lebih kecil
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %% [markdown]
# ### **2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!**

# %% [markdown]
# Red-Blue

# %%
img_rb = img.copy()
img_rb[:, :, 1] = 0
plt.imshow(cv.cvtColor(img_rb, cv.COLOR_BGR2RGB))

# %% [markdown]
# Green-Blue

# %%
img_gb = img.copy()
img_gb[:, :, 2] = 0  # Hapus channel merah
plt.imshow(cv.cvtColor(img_gb, cv.COLOR_BGR2RGB))

# %% [markdown]
# ### **3. Tampilkan image baris ke 20-115, kolom 25-120!**

# %%
# Menampilkan bagian tertentu dari gambar
img_crop = img[20:115, 25:120]
plt.imshow(cv.cvtColor(img_crop, cv.COLOR_BGR2RGB))

# %% [markdown]
# ### **4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!**

# %%
# Menampilkan channel merah saja untuk baris 5-30
img_red_channel = img[5:30, :, 2]
plt.imshow(img_red_channel, cmap='Reds')

# %% [markdown]
# ### **5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image**
# disarankan menggunakan bilangan acak/random!

# %%
import random

# Membuat gambar hitam dengan tipe data uint8
img_boxes = np.zeros((512, 512, 3), dtype=np.uint8)

# Menggambar 5 kotak dengan ukuran dan warna acak
for _ in range(5):
    pt1 = (random.randint(0, 400), random.randint(0, 400))  # Titik kiri atas
    pt2 = (pt1[0] + random.randint(50, 100), pt1[1] + random.randint(50, 100))  # Titik kanan bawah
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))  # Warna acak
    cv.rectangle(img_boxes, pt1=pt1, pt2=pt2, color=color, thickness=-1)

# Menampilkan gambar dengan kotak-kotak
plt.imshow(cv.cvtColor(img_boxes, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### **6. Tampilkan image dengan posisi terbalik!**

# %%
img_flipped_both = cv.flip(img_boxes, -1)  # Membalik secara vertikal dan horizontal
plt.imshow(cv.cvtColor(img_flipped_both, cv.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ### **Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :**
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/images/me.jpeg')
if img is None:
  print('Image not loaded. Check file path and permissions.')
else:
  img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

  top_left = (550, 800)  # Titik kiri atas rectangle
  bottom_right = (300, 550)  # Titik kanan bawah rectangle

  # Menggambar rectangle di sekitar wajah
  cv.rectangle(img_rgb, top_left, bottom_right, color=(0, 255, 0), thickness=5)

  center = (400, 650)  # Titik pusat lingkaran
  radius = 80  # Radius lingkaran

  # Menggambar circle di wajah kucing
  cv.circle(img_rgb, center=center, radius=radius, color=(255, 0, 0), thickness=5)

  plt.imshow(img_rgb)

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
# Membaca gambar kitten
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten.jpg')

# Check if image loaded successfully
if img is None:
  print('Image not loaded. Check file path and permissions.')
else:
  # Memisahkan channel BGR menjadi tiga channel terpisah
  B, G, R = cv.split(img)

  # Menentukan koordinat rectangle di sudut bawah kiri channel B
  height, width = B.shape  # Ukuran gambar
  top_left = (0, height - 50)  # Titik kiri atas rectangle
  bottom_right = (50, height)  # Titik kanan bawah rectangle

  # Menggambar rectangle di sudut bawah kiri channel B
  cv.rectangle(B, top_left, bottom_right, color=255, thickness=-1)  # Rectangle warna putih di channel B

  # Menggabungkan kembali channel R, G, B setelah menggambar rectangle di channel B
  merged_img = cv.merge([B, G, R])

  # Mengkonversi gambar ke RGB untuk ditampilkan dengan Matplotlib
  img_rgb = cv.cvtColor(merged_img, cv.COLOR_BGR2RGB)

  # Menampilkan gambar dengan rectangle di sudut bawah kiri channel B
  plt.imshow(img_rgb)
  plt.show()

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Membaca gambar kitten
img = cv.imread('/content/drive/MyDrive/PCVK/images/kitten.jpg')

# Memisahkan channel BGR menjadi tiga channel terpisah
B, G, R = cv.split(img)

# Menentukan koordinat rectangle di sudut bawah kiri channel B
height, width = B.shape  # Ukuran gambar
top_left = (0, height - 50)  # Titik kiri atas rectangle
bottom_right = (50, height)  # Titik kanan bawah rectangle

# Menggambar rectangle di sudut bawah kiri channel B
cv.rectangle(B, top_left, bottom_right, color=255, thickness=-1)  # Rectangle warna putih di channel B

# Menggabungkan kembali channel R, G, B setelah menggambar rectangle di channel B
merged_img = cv.merge([B, G, R])

# Menulis nama file pada citra (di bagian bawah gambar)
file_name = "kitten.jpg"
font = cv.FONT_HERSHEY_SIMPLEX  # Jenis font
font_scale = 0.5  # Ukuran font
color = (0, 0, 0)  # Warna font (hitam)
thickness = 1  # Ketebalan font
text_position = (50, height - 30)  # Koordinat untuk posisi teks

# Menambahkan teks ke gambar
cv.putText(merged_img, file_name, text_position, font, font_scale, color, thickness, cv.LINE_AA)

# Mengkonversi gambar ke RGB untuk ditampilkan dengan Matplotlib
img_rgb = cv.cvtColor(merged_img, cv.COLOR_BGR2RGB)

# Menampilkan gambar dengan nama file yang dituliskan
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# # **Tugas Kelompok**
# Kelompok 6 - tutup Pekerjaan dan kewarganegaraan.

# %%
link_ktp = cv.imread('/content/drive/MyDrive/PCVK/images/ktp.jpeg');

img_rgb = cv.cvtColor(link_ktp, cv.COLOR_BGR2RGB)

top_left = (190, 330)  # Titik kiri atas rectangle
bottom_right = (480, 340)  # Titik kanan bawah rectangle

# Menggambar rectangle di sekitar wajah kucing
cv.rectangle(img_rgb, top_left, bottom_right, color=(0, 255, 0), thickness=5)

center = (210, 360)  # Titik pusat lingkaran
radius = 10  # Radius lingkaran

# Menggambar circle di wajah kucing
cv.circle(img_rgb, center=center, radius=radius, color=(255, 0, 0), thickness=5)

plt.imshow(img_rgb)
